# %%
# Start writing code here...
#https://towardsdatascience.com/going-beyond-99-mnist-handwritten-digits-recognition-cfff96337392 
# https://www.ijert.org/research/multi-digit-number-classification-using-mnist-and-ann-IJERTV9IS050330.pdf
# https://github.com/thomalm/svhn-multi-digit

# %%
images = open('MNIST_synthetic.h5')
